# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.read_excel('SMH.xlsx')

# %%
df.head()
# Out:
#           Timestamp  Gender  Age Department  \
# 0  24-08-2022 22:32  Female   18        CSE
# 1  24-08-2022 22:52    Male   18        CSE
# 2  24-08-2022 22:57    Male   19        CSE
# 3  24-08-2022 23:04    Male   24        CSE
# 4  25-08-2022 19:20    Male   19        CSE
#
#   Are_you_happy_with_your_department_work_area  \
# 0                                          Yes
# 1                                          Yes
# 2                                          Yes
# 3                                           No
# 4                                          Yes
#
#   Why_did_you_chosen_your_department_work_area  \
# 0                                   Interested
# 1                                   Interested
# 2                                   Interested
# 3                                 Future scope
# 4            All are choosing so I also chosen
#
#    Current_year_you_are_studying_in  CGPA_SGPA    \
# 0                                 3         8.00
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Gender', 'Age', 'Department',
#        'Are_you_happy_with_your_department_work_area',
#        'Why_did_you_chosen_your_department_work_area',
#        'Current_year_you_are_studying_in', 'CGPA_SGPA  ',
#        'Are_you_having_proper_sleep_everyday',
#        'How_much_time_are_you_sleeping_everyday',
#        'Are_you_getting_good_food_diet_everyday', 'What_is_your_screen_time',
#        'On_what_do_you_spend_your_screen_time_more',
#        'From_where_you_are_getting_stress', 'When_you_are_stressed_more',
#        'What_will_you_like_to_do_when_you_are_stressed',
#        'How_did_you_felt_during_COVID_19_pandemic_period',
#        'concentrate_on_your_work_when_you_are_stressed'],
#       dtype='object')

# %%
px.scatter(df,x='Department',y='Are_you_happy_with_your_department_work_area',title='Are you happy with your department',
          template='plotly_dark',color='Are_you_happy_with_your_department_work_area',size='Age',animation_frame='Why_did_you_chosen_your_department_work_area',animation_group='Age')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df,x='How_did_you_felt_during_COVID_19_pandemic_period',y='concentrate_on_your_work_when_you_are_stressed',color='How_did_you_felt_during_COVID_19_pandemic_period',
      animation_frame='What_will_you_like_to_do_when_you_are_stressed',animation_group='How_did_you_felt_during_COVID_19_pandemic_period')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(df,x='Department',y='Are_you_happy_with_your_department_work_area',title='Are you happy with your department',
          template='plotly_dark',color='Are_you_happy_with_your_department_work_area',animation_frame='Why_did_you_chosen_your_department_work_area',animation_group='Age')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
